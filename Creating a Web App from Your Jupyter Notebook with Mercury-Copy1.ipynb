# %%
import numpy as np
import pandas as pd

# %%
weather=pd.read_csv('climate_change_data.csv')

# %%
weather
# Out:
#            Date           Location                Country  Temperature  \
# 0     01-Jan-00    New Williamtown                 Latvia    10.688986
# 1     01-Jan-00       North Rachel           South Africa    13.814430
# 2     01-Feb-00   West Williamland          French Guiana    27.323718
# 3     01-Mar-00        South David                Vietnam    12.309581
# 4     01-Apr-00     New Scottburgh                Moldova    13.210885
# ...         ...                ...                    ...          ...
# 9995  27-Dec-22   South Elaineberg                 Bhutan    15.020523
# 9996  28-Dec-22       Leblancville                  Congo    16.772451
# 9997  29-Dec-22     West Stephanie              Argentina    22.370025
# 9998  30-Dec-22        Port Steven                Albania    19.430853
# 9999  31-Dec-22  West Anthonyburgh  Sao Tome and Principe    12.661928
#
#       CO2 Emissions  Sea Level Rise  Precipitation   Humidity  Wind Speed  \
# ...

# %%
# //////weather['year'] = pd.to_datetime(weather['Date']).dt.year
# weather

# %%
# weather['month'] = pd.to_datetime(weather['Date']).dt.month
# weather

# %%
# weather

# %%
Year1='2023'

# %%
weather[weather['year1']==Year1].plot(y='Temperature', x='month1',    
   legend=False)
print(f"Monthly maximum temperatures for {Year1}")
# Out:
# Monthly maximum temperatures for 2023

# %%
year='2000'
weather[weather['year1']==year].plot(y='Humidity', x='month1',    
   legend=False)
print(f"Monthly maximum temperatures for {year}")
# Out:
# Monthly maximum temperatures for 2000

# %% [markdown]
# ## Mercury

# %%
pip install mljar-mercury
# Out:
# ...
#      ---------------------------------------- 4.5/4.5 MB 2.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      -------------------------------------- 126.3/126.3 kB 2.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 97.8/97.8 kB 1.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.5/1.5 MB 3.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 791.7/791.7 kB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.9/7.9 MB 2.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 81.4/81.4 kB 2.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 83.4/83.4 kB 2.4 MB/s eta 0:00:00
# ...

# %%
mercury add --notebook "http://localhost:8890/notebooks/Documents/Biz%20Azure/web.ipynb"
# Out:
#   File "C:\Users\IT Tech\AppData\Local\Temp\ipykernel_18508\2674936996.py", line 1
#     mercury add --notebook "http://localhost:8890/notebooks/Documents/Biz%20Azure/web.ipynb"
#             ^
# SyntaxError: invalid syntax

# %%
mercury run
# Out:
#   File "C:\Users\ITTECH~1\AppData\Local\Temp/ipykernel_8952/4065731860.py", line 1
#     mercury run
#             ^
# SyntaxError: invalid syntax
