# %%
import pandas as pd
import seaborn as sns
import matplotlib
import numpy as np 
from pandas.api.types import is_numeric_dtype

# %%
df=pd.read_csv("C:\\Users\\User\\Desktop\\Data\\Top250.csv")
df
# Out:
#      Rank           Restaurant  \
# 0       1           McDonald's
# 1       2            Starbucks
# 2       3          Chick-fil-A
# 3       4            Taco Bell
# 4       5          Burger King
# ..    ...                  ...
# 245   246      Rainforest Cafe
# 246   247                  PDQ
# 247   248        Lupe Tortilla
# 248   249  Cook-Out Restaurant
# 249   250             Jollibee
#
#                                                Content  Sales YOY_Sales  \
# 0                                                  NaN  40412      4.9%
# 1                                                  NaN  21380      8.6%
# 2    While Popeyes got a lot of the chicken buzz in...  11320     13.0%
# 3                                                  NaN  11293      9.0%
# 4                                                  NaN  10204      2.7%
# ..                                                 ...    ...       ...
# 245                                                NaN    129    -10.4%
# ...

# %%
df.head(5)
# Out:
#    Rank   Restaurant                                            Content  \
# 0     1   McDonald's                                                NaN
# 1     2    Starbucks                                                NaN
# 2     3  Chick-fil-A  While Popeyes got a lot of the chicken buzz in...
# 3     4    Taco Bell                                                NaN
# 4     5  Burger King                                                NaN
#
#    Sales YOY_Sales  Units YOY_Units Headquarters             Segment_Category
# 0  40412      4.9%  13846     -0.5%          NaN       Quick Service & Burger
# 1  21380      8.6%  15049      3.0%          NaN  Quick Service & Coffee Cafe
# 2  11320     13.0%   2470      5.0%          NaN      Quick Service & Chicken
# 3  11293      9.0%   6766      2.7%          NaN      Quick Service & Mexican
# 4  10204      2.7%   7346      0.2%          NaN       Quick Service & Burger

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              250 non-null    int64
#  1   Restaurant        250 non-null    object
#  2   Content           33 non-null     object
#  3   Sales             250 non-null    int64
#  4   YOY_Sales         250 non-null    object
#  5   Units             250 non-null    int64
#  6   YOY_Units         250 non-null    object
#  7   Headquarters      52 non-null     object
#  8   Segment_Category  250 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 17.7+ KB

# %%
df.describe(include="all")
# Out:
#               Rank  Restaurant  \
# count   250.000000         250
# unique         NaN         250
# top            NaN  McDonald's
# freq           NaN           1
# mean    125.500000         NaN
# std      72.312977         NaN
# min       1.000000         NaN
# 25%      63.250000         NaN
# 50%     125.500000         NaN
# 75%     187.750000         NaN
# max     250.000000         NaN
#
#                                                   Content        Sales  \
# count                                                  33    250.00000
# unique                                                 33          NaN
# top     While Popeyes got a lot of the chicken buzz in...          NaN
# freq                                                    1          NaN
# mean                                                  NaN   1242.74000
# std                                                   NaN   3365.22882
# min                                                   NaN    126.00000
# ...

# %%
df.isnull().sum()
# Out:
# Rank                  0
# Restaurant            0
# Content             217
# Sales                 0
# YOY_Sales             0
# Units                 0
# YOY_Units             0
# Headquarters        198
# Segment_Category      0
# dtype: int64

# %%
missing_count=df.isnull().sum() # the count of missing values
value_count =df.isnull().count() #the count of all values
missing_percentage = round(missing_count/value_count *100,2)
missing_df=pd.DataFrame({'count': missing_count, 'percentage':missing_percentage})
print(missing_df)
# Out:
#                   count  percentage
# Rank                  0         0.0
# Restaurant            0         0.0
# Content             217        86.8
# Sales                 0         0.0
# YOY_Sales             0         0.0
# Units                 0         0.0
# YOY_Units             0         0.0
# Headquarters        198        79.2
# Segment_Category      0         0.0

# %%
barchart=missing_df.plot.bar(y='percentage')
for index, percentage in enumerate(missing_percentage):
    barchart.text(index, percentage, str(percentage) + '%')

# %% [markdown]
# # 2. Feature Engineering

# %%
df['Restaurant_length']=df['Restaurant'].apply(len)
df
# Out:
#      Rank           Restaurant  \
# 0       1           McDonald's
# 1       2            Starbucks
# 2       3          Chick-fil-A
# 3       4            Taco Bell
# 4       5          Burger King
# ..    ...                  ...
# 245   246      Rainforest Cafe
# 246   247                  PDQ
# 247   248        Lupe Tortilla
# 248   249  Cook-Out Restaurant
# 249   250             Jollibee
#
#                                                Content  Sales YOY_Sales  \
# 0                                                  NaN  40412      4.9%
# 1                                                  NaN  21380      8.6%
# 2    While Popeyes got a lot of the chicken buzz in...  11320     13.0%
# 3                                                  NaN  11293      9.0%
# 4                                                  NaN  10204      2.7%
# ..                                                 ...    ...       ...
# 245                                                NaN    129    -10.4%
# ...

# %%
df['with_Content'] = np.where(df['Content'].isnull(), 'Yes', 'No')
df
# Out:
#      Rank           Restaurant  \
# 0       1           McDonald's
# 1       2            Starbucks
# 2       3          Chick-fil-A
# 3       4            Taco Bell
# 4       5          Burger King
# ..    ...                  ...
# 245   246      Rainforest Cafe
# 246   247                  PDQ
# 247   248        Lupe Tortilla
# 248   249  Cook-Out Restaurant
# 249   250             Jollibee
#
#                                                Content  Sales YOY_Sales  \
# 0                                                  NaN  40412      4.9%
# 1                                                  NaN  21380      8.6%
# 2    While Popeyes got a lot of the chicken buzz in...  11320     13.0%
# 3                                                  NaN  11293      9.0%
# 4                                                  NaN  10204      2.7%
# ..                                                 ...    ...       ...
# 245                                                NaN    129    -10.4%
# ...

# %%
df = df.drop(['Rank','Sales','Restaurant','YOY_Units'],axis=1)

# %%
num_list =[]

cat_list= []

for column in df:
    if is_numeric_dtype(df[column]):
        num_list.append(column)
    elif is_string.dtype(df [column]):
        cat_list.append(column)

print(num_list)

print(cat_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 6
#       3 cat_list= []
#       5 for column in df:
# ----> 6     if is_numeric_dtype(df[column]):
#       7         num_list.append(column)
#       8     elif is_string.dtype(df [column]):
#
# NameError: name 'is_numeric_dtype' is not defined

# %% [markdown]
# # Univariate Analysis

# %%
for column in df:
    plt.figure(column)
    plt.title(column)
    if is_numeric_dtype(df[column]):
        df[column].plot(kind='hist')
    elif is_string_dtype(df[column]):
        df[column].value_counts()[:10].plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 4
#       2 plt.figure(column)
#       3 plt.title(column)
# ----> 4 if is_numeric_dtype(df[column]):
#       5     df[column].plot(kind='hist')
#       6 elif is_string_dtype(df[column]):
#
# NameError: name 'is_numeric_dtype' is not defined

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# # 1. Numerical vs. Numerical → heat map or pairplot

# %%
correlation=df.corr()
sns.heatmap(correlation, cmap="GnBu", annot=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8804\2927775199.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.corr()
# <Axes: >

# %%
sns.pairplot(df,height=2.5)

# %% [markdown]
# # 2. Categorical vs. Categorical → countplot with hue

# %%
for i in range(0, len(cat_list)): 
               primary_cat =cat_list(i)
               for j in range(0, len(cat_list)):
                   secondary_cat=cat_list[j]
                   if secondary_cat != primary_cat:
                       plt.figure (figsize=(15,15))
                       chart=sns.countplot(
                       data=df,
                       x= prinary_cat,
                       hue= secondary_cat,
                       palette ='GnBu',
                       order=df[primary_cat].value_counts().iloc[:10].index #show only TOP10
                       )

# %% [markdown]
# # Categorical vs. Numerical → boxplot or pairplot with hue

# %%
for i in range(0, len(cat_list)):
    cat= cat_list[i]
    for j in range(0, len(num_list)):
        num=num_list[j]
        plt.figure(figsize=(15,15))
        sns.boxplot( x=cat, y= num, data = df, palette="GnBu")

# %%
for i in range(0, len(cat_list)):
    hue_cat = cat_list[i]
    sns.pairplot(df, hue = hue_cat)
