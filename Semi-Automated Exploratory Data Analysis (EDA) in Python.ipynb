# %% [markdown]
# ## Exploratory Data Analysis (EDA):
# EDA process that can be broken down into the following steps:
#
# 1.Know Your Data
#
# 2.Data Manipulation and Feature Engineering
#
# 3.Univariate Analysis
#
# 4.Multivariate Analysis

# %% [markdown]
# ### 1. Know Your Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from pandas.api.types import is_string_dtype, is_numeric_dtype

# %%
pwd()
# Out:
# 'C:\\Users\\anike'

# %%
df = pd.read_csv('D:\Bizmetric\Azure training\Datasets\medium_data.csv')
df.head(10)
# Out:
#    id                                                url  \
# 0   1  https://towardsdatascience.com/a-beginners-gui...
# 1   2  https://towardsdatascience.com/hands-on-graph-...
# 2   3  https://towardsdatascience.com/how-to-use-ggpl...
# 3   4  https://towardsdatascience.com/databricks-how-...
# 4   5  https://towardsdatascience.com/a-step-by-step-...
# 5   6  https://towardsdatascience.com/an-easy-introdu...
# 6   7  https://towardsdatascience.com/hypothesis-test...
# 7   8  https://towardsdatascience.com/introduction-to...
# 8   9  https://towardsdatascience.com/which-2020-cand...
# 9  10  https://towardsdatascience.com/what-if-ai-mode...
#
#                                                title  \
# 0  A Beginner’s Guide to Word Embedding with Gens...
# 1  Hands-on Graph Neural Networks with PyTorch & ...
# 2                       How to Use ggplot2 in Python
# 3  Databricks: How to Save Files in CSV on Your L...
# 4  A Step-by-Step Implementation of Gradient Desc...
# 5    An Easy Introduction to SQL for Data Scientists
# 6                      Hypothesis testing visualized
# 7  Introduction to Latent Matrix Factorization Re...
# 8       Which 2020 Candidate is the Best at Twitter?
# 9          What if AI model understanding were easy?
#
#                                             subtitle   image  claps responses  \
# 0                                                NaN   1.png    850         8
# 1                                                NaN   2.png   1100        11
# 2                   A Grammar of Graphics for Python   3.png    767         1
# 3            When I work on Python projects dealing…  4.jpeg    354         0
# 4                    One example of building neural…  5.jpeg    211         3
# 5                                                NaN  6.jpeg    563         1
# 6               Literally seeing how stat tests work   7.gif    276         1
# 7                                                NaN   8.png    126         2
# 8  A Data Analysis of the 2020 Democratic Candida...   9.png    188         3
# 9  See  analytics-for-AI in action in this What-I...  10.jpg    493         2
#
#    reading_time           publication        date
# 0             8  Towards Data Science  2019-05-30
# 1             9  Towards Data Science  2019-05-30
# 2             5  Towards Data Science  2019-05-30
# 3             4  Towards Data Science  2019-05-30
# 4             4  Towards Data Science  2019-05-30
# 5             8  Towards Data Science  2019-05-30
# 6            12  Towards Data Science  2019-05-30
# 7             5  Towards Data Science  2019-05-30
# 8             8  Towards Data Science  2019-05-30
# 9             8  Towards Data Science  2019-05-30

# %%
df1 = pd.read_csv('D:\Bizmetric\Azure training\Datasets\penguins.csv')
df1.head(10)
# Out:
#       Island  CulmenLength  CulmenDepth  FlipperLength  BodyMass  Species
# 0  Torgersen          39.1         18.7          181.0    3750.0        0
# 1  Torgersen          39.5         17.4          186.0    3800.0        0
# 2  Torgersen          40.3         18.0          195.0    3250.0        0
# 3  Torgersen           0.0          0.0            0.0       0.0        0
# 4  Torgersen          36.7         19.3          193.0    3450.0        0
# 5  Torgersen          39.3         20.6          190.0    3650.0        0
# 6  Torgersen          38.9         17.8          181.0    3625.0        0
# 7  Torgersen          39.2         19.6          195.0    4675.0        0
# 8  Torgersen          34.1         18.1          193.0    3475.0        0
# 9  Torgersen          42.0         20.2          190.0    4250.0        0

# %% [markdown]
# ### df.info()
# function gives the number of missing values for each column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6508 entries, 0 to 6507
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            6508 non-null   int64
#  1   url           6508 non-null   object
#  2   title         6508 non-null   object
#  3   subtitle      3479 non-null   object
#  4   image         6361 non-null   object
#  5   claps         6508 non-null   int64
#  6   responses     6508 non-null   object
#  7   reading_time  6508 non-null   int64
#  8   publication   6508 non-null   object
#  9   date          6508 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 508.6+ KB

# %% [markdown]
# ### describe():
# This function provides basic statistics of each column. By passing the parameter “include = ‘all’”,
#
# it outputs the value count, unique count, the top-frequency value of the categorical variables and count, mean, standard deviation, min, max, and percentile of numeric variables

# %%
df.describe(include='all')
# Out:
#                  id                                                url  \
# count   6508.000000                                               6508
# unique          NaN                                               6508
# top             NaN  https://towardsdatascience.com/a-beginners-gui...
# freq            NaN                                                  1
# mean    3254.500000                                                NaN
# std     1878.842108                                                NaN
# min        1.000000                                                NaN
# 25%     1627.750000                                                NaN
# 50%     3254.500000                                                NaN
# 75%     4881.250000                                                NaN
# max     6508.000000                                                NaN
#
#                       title  \
# count                  6508
# unique                 6504
# top     Lost in translation
# freq                      2
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN
#
#                                                  subtitle  image  \
# count                                                3479   6361
# unique                                               3470   6361
# top     <em class="markup--em markup--h4-em">A weekly ...  1.png
# freq                                                    5      1
# mean                                                  NaN    NaN
# std                                                   NaN    NaN
# min                                                   NaN    NaN
# 25%                                                   NaN    NaN
# 50%                                                   NaN    NaN
# 75%                                                   NaN    NaN
# max                                                   NaN    NaN
#
#                claps responses  reading_time  publication        date
# count    6508.000000      6508   6508.000000         6508        6508
# unique           NaN        56           NaN            7          50
# top              NaN         0           NaN  The Startup  2019-10-21
# freq             NaN      3396           NaN         3041         197
# mean      311.076060       NaN      6.134911          NaN         NaN
# std       950.789896       NaN      3.231918          NaN         NaN
# min         0.000000       NaN      0.000000          NaN         NaN
# 25%        54.000000       NaN      4.000000          NaN         NaN
# 50%       115.000000       NaN      5.000000          NaN         NaN
# 75%       268.250000       NaN      7.000000          NaN         NaN
# max     38000.000000       NaN     55.000000          NaN         NaN

# %% [markdown]
# ### Missing Values:
# function gives the number of missing values for each column.

# %%
df.isnull().sum()
# Out:
# id                 0
# url                0
# title              0
# subtitle        3029
# image            147
# claps              0
# responses          0
# reading_time       0
# publication        0
# date               0
# dtype: int64

# %%
missing_count=df.isnull().sum()
value_count=df.isnull().count()
missing_percentage=round(missing_count/value_count *100,2)
missing_df=pd.DataFrame({'count':missing_count,'percentage':missing_percentage})
print(missing_df)
# Out:
#               count  percentage
# id                0        0.00
# url               0        0.00
# title             0        0.00
# subtitle       3029       46.54
# image           147        2.26
# claps             0        0.00
# responses         0        0.00
# reading_time      0        0.00
# publication       0        0.00
# date              0        0.00

# %%
barchart=missing_df.plot.bar(y='percentage')

for index,percentage in enumerate(missing_percentage):
    barchart.text(index,percentage,str(percentage)+'%')

# %% [markdown]
# ## 2. Feature Engineering

# %%
#1. title → title_length;

df['title_length'] = df['title'].apply(len)

# %%
#2. url → with_url

df['with_url'] = np.where(df['url'].isnull(), 'Yes', 'No')

df
# Out:
#         id                                                url  \
# 0        1  https://towardsdatascience.com/a-beginners-gui...
# 1        2  https://towardsdatascience.com/hands-on-graph-...
# 2        3  https://towardsdatascience.com/how-to-use-ggpl...
# 3        4  https://towardsdatascience.com/databricks-how-...
# 4        5  https://towardsdatascience.com/a-step-by-step-...
# ...    ...                                                ...
# 6503  6504  https://medium.com/better-marketing/we-vs-i-ho...
# 6504  6505  https://medium.com/better-marketing/how-donald...
# 6505  6506  https://medium.com/better-marketing/content-an...
# 6506  6507  https://medium.com/better-marketing/5-question...
# 6507  6508  https://medium.com/better-marketing/how-to-wri...
#
#                                                   title  \
# 0     A Beginner’s Guide to Word Embedding with Gens...
# 1     Hands-on Graph Neural Networks with PyTorch & ...
# 2                          How to Use ggplot2 in Python
# 3     Databricks: How to Save Files in CSV on Your L...
# 4     A Step-by-Step Implementation of Gradient Desc...
# ...                                                 ...
# 6503  “We” vs “I” — How Should You Talk About Yourse...
# 6504                   How Donald Trump Markets Himself
# 6505      Content and Marketing Beyond Mass Consumption
# 6506  5 Questions All Copywriters Should Ask Clients...
# 6507             How To Write a Good Business Blog Post
#
#                                                subtitle      image  claps  \
# 0                                                   NaN      1.png    850
# 1                                                   NaN      2.png   1100
# 2                      A Grammar of Graphics for Python      3.png    767
# 3               When I work on Python projects dealing…     4.jpeg    354
# 4                       One example of building neural…     5.jpeg    211
# ...                                                 ...        ...    ...
# 6503              Basic copywriting choices with a big…   6504.jpg    661
# 6504  Lessons from who might be the most popular bra...  6505.jpeg    189
# 6505  How to acquire customers without wasting money...   6506.jpg    207
# 6506                           Save time and effort by…   6507.jpg    253
# 6507                    An A-to-Z guide for non-writers   6508.jpg    147
#
#      responses  reading_time           publication        date  title_length  \
# 0            8             8  Towards Data Science  2019-05-30            63
# 1           11             9  Towards Data Science  2019-05-30            63
# 2            1             5  Towards Data Science  2019-05-30            28
# 3            0             4  Towards Data Science  2019-05-30            59
# 4            3             4  Towards Data Science  2019-05-30            69
# ...        ...           ...                   ...         ...           ...
# 6503         6             6      Better Marketing  2019-12-05            65
# 6504         1             5      Better Marketing  2019-12-05            32
# 6505         1             8      Better Marketing  2019-12-05            45
# 6506         2             5      Better Marketing  2019-12-05            78
# 6507         0             9      Better Marketing  2019-12-05            38
#
#      with_url
# 0          No
# 1          No
# 2          No
# 3          No
# 4          No
# ...       ...
# 6503       No
# 6504       No
# 6505       No
# 6506       No
# 6507       No
#
# [6508 rows x 12 columns]

# %%
#3. date→ month

df['month'] = pd.to_datetime(df['date']).dt.month.apply(str)
df
# Out:
#         id                                                url  \
# 0        1  https://towardsdatascience.com/a-beginners-gui...
# 1        2  https://towardsdatascience.com/hands-on-graph-...
# 2        3  https://towardsdatascience.com/how-to-use-ggpl...
# 3        4  https://towardsdatascience.com/databricks-how-...
# 4        5  https://towardsdatascience.com/a-step-by-step-...
# ...    ...                                                ...
# 6503  6504  https://medium.com/better-marketing/we-vs-i-ho...
# 6504  6505  https://medium.com/better-marketing/how-donald...
# 6505  6506  https://medium.com/better-marketing/content-an...
# 6506  6507  https://medium.com/better-marketing/5-question...
# 6507  6508  https://medium.com/better-marketing/how-to-wri...
#
#                                                   title  \
# 0     A Beginner’s Guide to Word Embedding with Gens...
# 1     Hands-on Graph Neural Networks with PyTorch & ...
# 2                          How to Use ggplot2 in Python
# 3     Databricks: How to Save Files in CSV on Your L...
# 4     A Step-by-Step Implementation of Gradient Desc...
# ...                                                 ...
# 6503  “We” vs “I” — How Should You Talk About Yourse...
# 6504                   How Donald Trump Markets Himself
# 6505      Content and Marketing Beyond Mass Consumption
# 6506  5 Questions All Copywriters Should Ask Clients...
# 6507             How To Write a Good Business Blog Post
#
#                                                subtitle      image  claps  \
# 0                                                   NaN      1.png    850
# 1                                                   NaN      2.png   1100
# 2                      A Grammar of Graphics for Python      3.png    767
# 3               When I work on Python projects dealing…     4.jpeg    354
# 4                       One example of building neural…     5.jpeg    211
# ...                                                 ...        ...    ...
# 6503              Basic copywriting choices with a big…   6504.jpg    661
# 6504  Lessons from who might be the most popular bra...  6505.jpeg    189
# 6505  How to acquire customers without wasting money...   6506.jpg    207
# 6506                           Save time and effort by…   6507.jpg    253
# 6507                    An A-to-Z guide for non-writers   6508.jpg    147
#
#      responses  reading_time           publication        date  title_length  \
# 0            8             8  Towards Data Science  2019-05-30            63
# 1           11             9  Towards Data Science  2019-05-30            63
# 2            1             5  Towards Data Science  2019-05-30            28
# 3            0             4  Towards Data Science  2019-05-30            59
# 4            3             4  Towards Data Science  2019-05-30            69
# ...        ...           ...                   ...         ...           ...
# 6503         6             6      Better Marketing  2019-12-05            65
# 6504         1             5      Better Marketing  2019-12-05            32
# 6505         1             8      Better Marketing  2019-12-05            45
# 6506         2             5      Better Marketing  2019-12-05            78
# 6507         0             9      Better Marketing  2019-12-05            38
#
#      with_url month
# 0          No     5
# 1          No     5
# 2          No     5
# 3          No     5
# 4          No     5
# ...       ...   ...
# 6503       No    12
# 6504       No    12
# 6505       No    12
# 6506       No    12
# 6507       No    12
#
# [6508 rows x 13 columns]

# %%
# df = df.drop(['url'],axis=1)

df
# Out:
#         id                                              title  \
# 0        1  A Beginner’s Guide to Word Embedding with Gens...
# 1        2  Hands-on Graph Neural Networks with PyTorch & ...
# 2        3                       How to Use ggplot2 in Python
# 3        4  Databricks: How to Save Files in CSV on Your L...
# 4        5  A Step-by-Step Implementation of Gradient Desc...
# ...    ...                                                ...
# 6503  6504  “We” vs “I” — How Should You Talk About Yourse...
# 6504  6505                   How Donald Trump Markets Himself
# 6505  6506      Content and Marketing Beyond Mass Consumption
# 6506  6507  5 Questions All Copywriters Should Ask Clients...
# 6507  6508             How To Write a Good Business Blog Post
#
#                                                subtitle      image  claps  \
# 0                                                   NaN      1.png    850
# 1                                                   NaN      2.png   1100
# 2                      A Grammar of Graphics for Python      3.png    767
# 3               When I work on Python projects dealing…     4.jpeg    354
# 4                       One example of building neural…     5.jpeg    211
# ...                                                 ...        ...    ...
# 6503              Basic copywriting choices with a big…   6504.jpg    661
# 6504  Lessons from who might be the most popular bra...  6505.jpeg    189
# 6505  How to acquire customers without wasting money...   6506.jpg    207
# 6506                           Save time and effort by…   6507.jpg    253
# 6507                    An A-to-Z guide for non-writers   6508.jpg    147
#
#      responses  reading_time           publication        date  title_length  \
# 0            8             8  Towards Data Science  2019-05-30            63
# 1           11             9  Towards Data Science  2019-05-30            63
# 2            1             5  Towards Data Science  2019-05-30            28
# 3            0             4  Towards Data Science  2019-05-30            59
# 4            3             4  Towards Data Science  2019-05-30            69
# ...        ...           ...                   ...         ...           ...
# 6503         6             6      Better Marketing  2019-12-05            65
# 6504         1             5      Better Marketing  2019-12-05            32
# 6505         1             8      Better Marketing  2019-12-05            45
# 6506         2             5      Better Marketing  2019-12-05            78
# 6507         0             9      Better Marketing  2019-12-05            38
#
#      with_url month
# 0          No     5
# 1          No     5
# 2          No     5
# 3          No     5
# 4          No     5
# ...       ...   ...
# 6503       No    12
# 6504       No    12
# 6505       No    12
# 6506       No    12
# 6507       No    12
#
# [6508 rows x 12 columns]

# %%
df1 = df1.drop(['FlipperLength', 'CulmenDepth'],axis=1)

# df1

# %%
df1
# Out:
#         Island  CulmenLength  BodyMass  Species
# 0    Torgersen          39.1    3750.0        0
# 1    Torgersen          39.5    3800.0        0
# 2    Torgersen          40.3    3250.0        0
# 3    Torgersen           0.0       0.0        0
# 4    Torgersen          36.7    3450.0        0
# ..         ...           ...       ...      ...
# 339      Dream          55.8    4000.0        2
# 340      Dream          43.5    3400.0        2
# 341      Dream          49.6    3775.0        2
# 342      Dream          50.8    4100.0        2
# 343      Dream          50.2    3775.0        2
#
# [344 rows x 4 columns]

# %%
#populate the list of numeric attributes and categorical attributes
num_list=[]
cat_list=[]
for column in df:
    if is_numeric_dtype(df[column]):
        num_list.append(column)
    elif is_string_dtype(df[column]):
        cat_list.append(column)
        
print(num_list)
print(cat_list)
# Out:
# ['id', 'claps', 'reading_time', 'title_length']
# ['title', 'subtitle', 'image', 'responses', 'publication', 'date', 'with_url', 'month']

# %%
#populate the list of numeric attributes and categorical attributes
num_list=[]
cat_list=[]
for column in df1:
    if is_numeric_dtype(df1[column]):
        num_list.append(column)
    elif is_string_dtype(df1[column]):
        cat_list.append(column)
        
print(num_list)
print(cat_list)
# Out:
# ['CulmenLength', 'BodyMass', 'Species']
# ['Island']

# %% [markdown]
# After finalizing the numerical and categorical variables lists, the univariate and multivariate analysis can be automated.

# %% [markdown]
# ## 3. Univariate Analysis:
# The describe() function mentioned in the first section has already provided a univariate analysis in a non-graphical way. In this section, we will be generating more insights by visualizing the data and spot the hidden patterns through graphical analysis.

# %%
for column in df:
    plt.figure(column)
    plt.title(column)
    if is_numeric_dtype(df[column]):
        df[column].plot(kind='hist')
    elif is_string_dtype(df[column]):
        df[column].value_counts()[:10].plot(kind='bar')

# %%
for column in df1:
    plt.figure(column)
    plt.title(column)
    if is_numeric_dtype(df1[column]):
        df1[column].plot(kind='hist')
    elif is_string_dtype(df1[column]):
        df1[column].value_counts()[:10].plot(kind='bar')

# %% [markdown]
# ## 4. Multivariate Analysis

# %% [markdown]
# Multivariate analysis is categorized into these three conditions to address various combinations of numerical variables and categorical variables.
#
# 1. Numerical vs. Numerical → heat map or pairplot
# 2. Categorical vs. Categorical → countplot with hue
# 3. Categorical vs. Numerical → boxplot or pairplot with hue

# %% [markdown]
# ### 1. Numerical vs. Numerical → heat map or pairplot

# %%
correlation=df.corr()
sns.heatmap(correlation, cmap='GnBu', annot=True)
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_14356\1365641800.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.corr()
# <Axes: >

# %%
correlation=df1.corr()
sns.heatmap(correlation, cmap='GnBu', annot=True)
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_14356\359676674.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df1.corr()
# <Axes: >

# %%
#pairplot
sns.pairplot(df,height=2.5)

# %% [markdown]
# Pair plot or scatterplot is a good complementary to the correlation matrix, especially when nonlinear relationships (e.g. exponential, inverse relationship) might exist. For example, the inverse relationship between “Rank” and “Sales” observed in the restaurant dataset may be mistaken as strong linear relationship if we simply look at number “- 0.92” the correlation matrix.

# %% [markdown]
# ### 2. Categorical vs. Categorical → countplot with hue

# %%
for i in range(0,len(cat_list)):
    primary_cat=cat_list[i]
    for j in range(0,len(cat_list)):
        secondary_cat=cat_list[j]
        if secondary_cat!=primary_cat:
            plt.figure(figsize=(15,15))
            chart=sns.countplot(
                data=df1,
                x=primary_cat,
                hue=secondary_cat,
                palette='GnBu',
                order=df[primary_cat].value_counts().iloc[:10].index
            )#show only top 10

# %% [markdown]
# ### 3. Categorical vs. Numerical → boxplot or pairplot with hue

# %% [markdown]
# Box plot is usually used when we need to compare how numerical data varies across groups.

# %%
for i in range(0,len(cat_list)):
    cat=cat_list[i]
    for i in range(0,len(num_list)):
        num=num_list[j]
        plt.figure(figsize=(15,15))
        sns.boxplot(x=cat,y=num,data=df1)

# %%
for i in range(0,len(cat_list)):
    hue_cat=cat_list[i]
    sns.pairplot(df1,hue=hue_cat)
