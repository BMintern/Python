# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
weather=pd.read_csv('climate_change_data.csv')

# %%
weather
# Out:
#            Date           Location                Country  Temperature  \
# 0     01-Jan-00    New Williamtown                 Latvia    10.688986
# 1     01-Jan-00       North Rachel           South Africa    13.814430
# 2     01-Feb-00   West Williamland          French Guiana    27.323718
# 3     01-Mar-00        South David                Vietnam    12.309581
# 4     01-Apr-00     New Scottburgh                Moldova    13.210885
# ...         ...                ...                    ...          ...
# 9995  27-Dec-22   South Elaineberg                 Bhutan    15.020523
# 9996  28-Dec-22       Leblancville                  Congo    16.772451
# 9997  29-Dec-22     West Stephanie              Argentina    22.370025
# 9998  30-Dec-22        Port Steven                Albania    19.430853
# 9999  31-Dec-22  West Anthonyburgh  Sao Tome and Principe    12.661928
#
#       CO2 Emissions  Sea Level Rise  Precipitation   Humidity  Wind Speed  \
# 0        403.118902        0.717506      13.835237  23.631256   18.492026
# 1        396.663499        1.205715      40.974084  43.982946   34.249300
# 2        451.553155       -0.160783      42.697931  96.652600   34.124261
# 3        422.404984       -0.475931       5.193341  47.467938    8.554563
# 4        410.472999        1.135757      78.695280  61.789672    8.001164
# ...             ...             ...            ...        ...         ...
# 9995     391.379537       -1.452243      93.417109  25.293814    6.531866
# 9996     346.921190        0.543616      49.882947  96.787402   42.249014
# 9997     466.042136        1.026704      30.659841  15.211825   18.293708
# 9998     337.899776       -0.895329      18.932275  82.774520   42.424255
# 9999     381.172746        2.260788      78.339658  99.243923   41.856539
#
#       day  month1  year1
# 0       1       1   2000
# 1       1       1   2000
# 2       1       2   2000
# 3       1       3   2000
# 4       1       4   2000
# ...   ...     ...    ...
# 9995   27      12   2022
# 9996   28      12   2022
# 9997   29      12   2022
# 9998   30      12   2022
# 9999   31      12   2022
#
# [10000 rows x 12 columns]

# %%
weather['year'] = pd.to_datetime(weather['Date']).dt.year
weather
# Out:
#            Date           Location                Country  Temperature  \
# 0     01-Jan-00    New Williamtown                 Latvia    10.688986
# 1     01-Jan-00       North Rachel           South Africa    13.814430
# 2     01-Feb-00   West Williamland          French Guiana    27.323718
# 3     01-Mar-00        South David                Vietnam    12.309581
# 4     01-Apr-00     New Scottburgh                Moldova    13.210885
# ...         ...                ...                    ...          ...
# 9995  27-Dec-22   South Elaineberg                 Bhutan    15.020523
# 9996  28-Dec-22       Leblancville                  Congo    16.772451
# 9997  29-Dec-22     West Stephanie              Argentina    22.370025
# 9998  30-Dec-22        Port Steven                Albania    19.430853
# 9999  31-Dec-22  West Anthonyburgh  Sao Tome and Principe    12.661928
#
#       CO2 Emissions  Sea Level Rise  Precipitation   Humidity  Wind Speed  \
# 0        403.118902        0.717506      13.835237  23.631256   18.492026
# 1        396.663499        1.205715      40.974084  43.982946   34.249300
# 2        451.553155       -0.160783      42.697931  96.652600   34.124261
# 3        422.404984       -0.475931       5.193341  47.467938    8.554563
# 4        410.472999        1.135757      78.695280  61.789672    8.001164
# ...             ...             ...            ...        ...         ...
# 9995     391.379537       -1.452243      93.417109  25.293814    6.531866
# 9996     346.921190        0.543616      49.882947  96.787402   42.249014
# 9997     466.042136        1.026704      30.659841  15.211825   18.293708
# 9998     337.899776       -0.895329      18.932275  82.774520   42.424255
# 9999     381.172746        2.260788      78.339658  99.243923   41.856539
#
#       day  month1  year1  year
# 0       1       1   2000  2000
# 1       1       1   2000  2000
# 2       1       2   2000  2000
# 3       1       3   2000  2000
# 4       1       4   2000  2000
# ...   ...     ...    ...   ...
# 9995   27      12   2022  2022
# 9996   28      12   2022  2022
# 9997   29      12   2022  2022
# 9998   30      12   2022  2022
# 9999   31      12   2022  2022
#
# [10000 rows x 13 columns]

# %%
weather['month'] = pd.to_datetime(weather['Date']).dt.month
weather
# Out:
#            Date           Location                Country  Temperature  \
# 0     01-Jan-00    New Williamtown                 Latvia    10.688986
# 1     01-Jan-00       North Rachel           South Africa    13.814430
# 2     01-Feb-00   West Williamland          French Guiana    27.323718
# 3     01-Mar-00        South David                Vietnam    12.309581
# 4     01-Apr-00     New Scottburgh                Moldova    13.210885
# ...         ...                ...                    ...          ...
# 9995  27-Dec-22   South Elaineberg                 Bhutan    15.020523
# 9996  28-Dec-22       Leblancville                  Congo    16.772451
# 9997  29-Dec-22     West Stephanie              Argentina    22.370025
# 9998  30-Dec-22        Port Steven                Albania    19.430853
# 9999  31-Dec-22  West Anthonyburgh  Sao Tome and Principe    12.661928
#
#       CO2 Emissions  Sea Level Rise  Precipitation   Humidity  Wind Speed  \
# 0        403.118902        0.717506      13.835237  23.631256   18.492026
# 1        396.663499        1.205715      40.974084  43.982946   34.249300
# 2        451.553155       -0.160783      42.697931  96.652600   34.124261
# 3        422.404984       -0.475931       5.193341  47.467938    8.554563
# 4        410.472999        1.135757      78.695280  61.789672    8.001164
# ...             ...             ...            ...        ...         ...
# 9995     391.379537       -1.452243      93.417109  25.293814    6.531866
# 9996     346.921190        0.543616      49.882947  96.787402   42.249014
# 9997     466.042136        1.026704      30.659841  15.211825   18.293708
# 9998     337.899776       -0.895329      18.932275  82.774520   42.424255
# 9999     381.172746        2.260788      78.339658  99.243923   41.856539
#
#       day  month1  year1  year  month
# 0       1       1   2000  2000      1
# 1       1       1   2000  2000      1
# 2       1       2   2000  2000      2
# 3       1       3   2000  2000      3
# 4       1       4   2000  2000      4
# ...   ...     ...    ...   ...    ...
# 9995   27      12   2022  2022     12
# 9996   28      12   2022  2022     12
# 9997   29      12   2022  2022     12
# 9998   30      12   2022  2022     12
# 9999   31      12   2022  2022     12
#
# [10000 rows x 14 columns]

# %%
weather
# Out:
#            Date           Location                Country  Temperature  \
# 0     01-Jan-00    New Williamtown                 Latvia    10.688986
# 1     01-Jan-00       North Rachel           South Africa    13.814430
# 2     01-Feb-00   West Williamland          French Guiana    27.323718
# 3     01-Mar-00        South David                Vietnam    12.309581
# 4     01-Apr-00     New Scottburgh                Moldova    13.210885
# ...         ...                ...                    ...          ...
# 9995  27-Dec-22   South Elaineberg                 Bhutan    15.020523
# 9996  28-Dec-22       Leblancville                  Congo    16.772451
# 9997  29-Dec-22     West Stephanie              Argentina    22.370025
# 9998  30-Dec-22        Port Steven                Albania    19.430853
# 9999  31-Dec-22  West Anthonyburgh  Sao Tome and Principe    12.661928
#
#       CO2 Emissions  Sea Level Rise  Precipitation   Humidity  Wind Speed  \
# 0        403.118902        0.717506      13.835237  23.631256   18.492026
# 1        396.663499        1.205715      40.974084  43.982946   34.249300
# 2        451.553155       -0.160783      42.697931  96.652600   34.124261
# 3        422.404984       -0.475931       5.193341  47.467938    8.554563
# 4        410.472999        1.135757      78.695280  61.789672    8.001164
# ...             ...             ...            ...        ...         ...
# 9995     391.379537       -1.452243      93.417109  25.293814    6.531866
# 9996     346.921190        0.543616      49.882947  96.787402   42.249014
# 9997     466.042136        1.026704      30.659841  15.211825   18.293708
# 9998     337.899776       -0.895329      18.932275  82.774520   42.424255
# 9999     381.172746        2.260788      78.339658  99.243923   41.856539
#
#       day  month1  year1  year  month
# 0       1       1   2000  2000      1
# 1       1       1   2000  2000      1
# 2       1       2   2000  2000      2
# 3       1       3   2000  2000      3
# 4       1       4   2000  2000      4
# ...   ...     ...    ...   ...    ...
# 9995   27      12   2022  2022     12
# 9996   28      12   2022  2022     12
# 9997   29      12   2022  2022     12
# 9998   30      12   2022  2022     12
# 9999   31      12   2022  2022     12
#
# [10000 rows x 14 columns]

# %%
year='2000'

# %%
weather[weather['year1']==year].plot(y='Humidity', x='month1',legend=False)
print(f"Monthly maximum temperatures for {year}")
# Out:
# Monthly maximum temperatures for 2000

# %% [markdown]
# ## Mercury

# %%
pip install mljar-mercury
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mljar-mercury
#   Downloading mljar-mercury-1.1.6.tar.gz (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 44.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting django==3.2.5 (from mljar-mercury)
#   Downloading Django-3.2.5-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 104.1 MB/s eta 0:00:00
# Collecting djangorestframework==3.12.4 (from mljar-mercury)
#   Downloading djangorestframework-3.12.4-py3-none-any.whl (957 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 957.7/957.7 kB 62.6 MB/s eta 0:00:00
# Collecting django-filter==21.1 (from mljar-mercury)
#   Downloading django_filter-21.1-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 10.8 MB/s eta 0:00:00
# Collecting markdown==3.3.6 (from mljar-mercury)
#   Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 kB 11.9 MB/s eta 0:00:00
# Collecting celery==5.1.2 (from mljar-mercury)
#   Downloading celery-5.1.2-py3-none-any.whl (401 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.9/401.9 kB 43.6 MB/s eta 0:00:00
# Collecting sqlalchemy==1.4.27 (from mljar-mercury)
#   Downloading SQLAlchemy-1.4.27-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 108.1 MB/s eta 0:00:00
# Collecting gevent==21.12.0 (from mljar-mercury)
#   Downloading gevent-21.12.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 136.3 MB/s eta 0:00:00
# Requirement already satisfied: nbconvert>=6.5.0 in /usr/local/lib/python3.10/dist-packages (from mljar-mercury) (6.5.4)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from mljar-mercury) (0.2.0)
# Requirement already satisfied: pyyaml==6.0 in /usr/local/lib/python3.10/dist-packages (from mljar-mercury) (6.0)
# Collecting django-cors-headers==3.10.1 (from mljar-mercury)
#   Downloading django_cors_headers-3.10.1-py3-none-any.whl (12 kB)
# Collecting ipython==7.30.1 (from mljar-mercury)
#   Downloading ipython-7.30.1-py3-none-any.whl (791 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 791.7/791.7 kB 68.6 MB/s eta 0:00:00
# Collecting ipykernel==6.6.0 (from mljar-mercury)
#   Downloading ipykernel-6.6.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.3/126.3 kB 17.5 MB/s eta 0:00:00
# Collecting psutil==5.8.0 (from mljar-mercury)
#   Downloading psutil-5.8.0.tar.gz (470 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 470.9/470.9 kB 53.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting whitenoise==5.3.0 (from mljar-mercury)
#   Downloading whitenoise-5.3.0-py2.py3-none-any.whl (19 kB)
# Collecting python-dotenv==0.19.2 (from mljar-mercury)
#   Downloading python_dotenv-0.19.2-py2.py3-none-any.whl (17 kB)
# Collecting django-drf-filepond==0.4.1 (from mljar-mercury)
#   Downloading django_drf_filepond-0.4.1-py2.py3-none-any.whl (39 kB)
# Collecting croniter==1.3.5 (from mljar-mercury)
#   Downloading croniter-1.3.5-py2.py3-none-any.whl (17 kB)
# Collecting pyppeteer==1.0.2 (from mljar-mercury)
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: pytz>dev in /usr/local/lib/python3.10/dist-packages (from celery==5.1.2->mljar-mercury) (2022.7.1)
# Collecting billiard<4.0,>=3.6.4.0 (from celery==5.1.2->mljar-mercury)
#   Downloading billiard-3.6.4.0-py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 12.1 MB/s eta 0:00:00
# Collecting kombu<6.0,>=5.1.0 (from celery==5.1.2->mljar-mercury)
#   Downloading kombu-5.3.1-py3-none-any.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.5/198.5 kB 26.2 MB/s eta 0:00:00
# Collecting vine<6.0,>=5.0.0 (from celery==5.1.2->mljar-mercury)
#   Downloading vine-5.0.0-py2.py3-none-any.whl (9.4 kB)
# Collecting click<8.0,>=7.0 (from celery==5.1.2->mljar-mercury)
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 12.3 MB/s eta 0:00:00
# Collecting click-didyoumean>=0.0.3 (from celery==5.1.2->mljar-mercury)
#   Downloading click_didyoumean-0.3.0-py3-none-any.whl (2.7 kB)
# Collecting click-repl>=0.1.6 (from celery==5.1.2->mljar-mercury)
#   Downloading click_repl-0.3.0-py3-none-any.whl (10 kB)
# Collecting click-plugins>=1.1.1 (from celery==5.1.2->mljar-mercury)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from celery==5.1.2->mljar-mercury) (67.7.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from croniter==1.3.5->mljar-mercury) (2.8.2)
# Collecting asgiref<4,>=3.3.2 (from django==3.2.5->mljar-mercury)
#   Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: sqlparse>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from django==3.2.5->mljar-mercury) (0.4.4)
# Requirement already satisfied: requests>=2.20.1 in /usr/local/lib/python3.10/dist-packages (from django-drf-filepond==0.4.1->mljar-mercury) (2.27.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from django-drf-filepond==0.4.1->mljar-mercury) (1.16.0)
# Collecting shortuuid>=0.5.0 (from django-drf-filepond==0.4.1->mljar-mercury)
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Collecting django-storages>=1.9.1 (from django-drf-filepond==0.4.1->mljar-mercury)
#   Downloading django_storages-1.13.2-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 6.0 MB/s eta 0:00:00
# Collecting zope.event (from gevent==21.12.0->mljar-mercury)
#   Downloading zope.event-4.6-py2.py3-none-any.whl (6.8 kB)
# Collecting zope.interface (from gevent==21.12.0->mljar-mercury)
#   Downloading zope.interface-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 28.4 MB/s eta 0:00:00
# Collecting greenlet<2.0,>=1.1.0 (from gevent==21.12.0->mljar-mercury)
#   Downloading greenlet-1.1.3.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 kB 20.2 MB/s eta 0:00:00
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel==6.6.0->mljar-mercury) (1.6.6)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel==6.6.0->mljar-mercury) (5.7.1)
# Requirement already satisfied: jupyter-client<8.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel==6.6.0->mljar-mercury) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel==6.6.0->mljar-mercury) (6.3.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel==6.6.0->mljar-mercury) (0.1.6)
# Collecting jedi>=0.16 (from ipython==7.30.1->mljar-mercury)
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 102.7 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython==7.30.1->mljar-mercury) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython==7.30.1->mljar-mercury) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython==7.30.1->mljar-mercury) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython==7.30.1->mljar-mercury) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython==7.30.1->mljar-mercury) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython==7.30.1->mljar-mercury) (4.8.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from pyppeteer==1.0.2->mljar-mercury) (1.4.4)
# Requirement already satisfied: certifi>=2021 in /usr/local/lib/python3.10/dist-packages (from pyppeteer==1.0.2->mljar-mercury) (2022.12.7)
# Collecting importlib-metadata>=1.4 (from pyppeteer==1.0.2->mljar-mercury)
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Collecting pyee<9.0.0,>=8.1.0 (from pyppeteer==1.0.2->mljar-mercury)
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from pyppeteer==1.0.2->mljar-mercury) (4.65.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /usr/local/lib/python3.10/dist-packages (from pyppeteer==1.0.2->mljar-mercury) (1.26.15)
# Collecting websockets<11.0,>=10.0 (from pyppeteer==1.0.2->mljar-mercury)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.5.0->mljar-mercury) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.5.0->mljar-mercury) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.5.0->mljar-mercury) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.5.0->mljar-mercury) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.5.0->mljar-mercury) (0.4)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.5.0->mljar-mercury) (3.1.2)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.5.0->mljar-mercury) (5.3.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.5.0->mljar-mercury) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.5.0->mljar-mercury) (2.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.5.0->mljar-mercury) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.5.0->mljar-mercury) (0.7.4)
# Requirement already satisfied: nbformat>=5.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.5.0->mljar-mercury) (5.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.5.0->mljar-mercury) (23.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.5.0->mljar-mercury) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.5.0->mljar-mercury) (1.2.1)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from asgiref<4,>=3.3.2->django==3.2.5->mljar-mercury) (4.5.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->pyppeteer==1.0.2->mljar-mercury) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython==7.30.1->mljar-mercury) (0.8.3)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client<8.0->ipykernel==6.6.0->mljar-mercury) (23.2.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.7->nbconvert>=6.5.0->mljar-mercury) (3.3.0)
# Collecting amqp<6.0.0,>=5.1.1 (from kombu<6.0,>=5.1.0->celery==5.1.2->mljar-mercury)
#   Downloading amqp-5.1.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert>=6.5.0->mljar-mercury) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert>=6.5.0->mljar-mercury) (4.3.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython==7.30.1->mljar-mercury) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython==7.30.1->mljar-mercury) (0.2.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.1->django-drf-filepond==0.4.1->mljar-mercury) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.1->django-drf-filepond==0.4.1->mljar-mercury) (3.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=6.5.0->mljar-mercury) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=6.5.0->mljar-mercury) (0.5.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.5.0->mljar-mercury) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.5.0->mljar-mercury) (0.19.3)
# Building wheels for collected packages: mljar-mercury, psutil
#   Building wheel for mljar-mercury (pyproject.toml) ... done
#   Created wheel for mljar-mercury: filename=mljar_mercury-1.1.6-py3-none-any.whl size=4582614 sha256=38642df4c442c1c0c202826a19bca0a2cbf98a9c5aeb38477915ae74abfba6da
#   Stored in directory: /root/.cache/pip/wheels/7c/8a/da/56adfc53dc67bfe68d6bf37b645dc7403ed229a37a4ea69cac
#   Building wheel for psutil (setup.py) ... done
#   Created wheel for psutil: filename=psutil-5.8.0-cp310-cp310-linux_x86_64.whl size=299077 sha256=17b9d8f2107327232894d8a079565e8d1bf71b0ed3a6dce965fa2b45787e9381
#   Stored in directory: /root/.cache/pip/wheels/12/a3/6d/615295409067d58a62a069d30d296d61d3ac132605e3a9555c
# Successfully built mljar-mercury psutil
# Installing collected packages: pyee, billiard, zope.interface, zope.event, whitenoise, websockets, vine, shortuuid, python-dotenv, psutil, markdown, jedi, importlib-metadata, greenlet, click, asgiref, sqlalchemy, pyppeteer, ipython, gevent, django, croniter, click-repl, click-plugins, click-didyoumean, amqp, kombu, ipykernel, djangorestframework, django-storages, django-filter, django-cors-headers, django-drf-filepond, celery, mljar-mercury
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.4.3
#     Uninstalling Markdown-3.4.3:
#       Successfully uninstalled Markdown-3.4.3
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 2.0.2
#     Uninstalling greenlet-2.0.2:
#       Successfully uninstalled greenlet-2.0.2
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.10
#     Uninstalling SQLAlchemy-2.0.10:
#       Successfully uninstalled SQLAlchemy-2.0.10
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.5.6
#     Uninstalling ipykernel-5.5.6:
#       Successfully uninstalled ipykernel-5.5.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 2.2.4 requires click>=8.0, but you have click 7.1.2 which is incompatible.
# google-colab 1.0.0 requires ipykernel==5.5.6, but you have ipykernel 6.6.0 which is incompatible.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 7.30.1 which is incompatible.
# pip-tools 6.13.0 requires click>=8, but you have click 7.1.2 which is incompatible.
# Successfully installed amqp-5.1.1 asgiref-3.7.2 billiard-3.6.4.0 celery-5.1.2 click-7.1.2 click-didyoumean-0.3.0 click-plugins-1.1.1 click-repl-0.3.0 croniter-1.3.5 django-3.2.5 django-cors-headers-3.10.1 django-drf-filepond-0.4.1 django-filter-21.1 django-storages-1.13.2 djangorestframework-3.12.4 gevent-21.12.0 greenlet-1.1.3.post0 importlib-metadata-6.7.0 ipykernel-6.6.0 ipython-7.30.1 jedi-0.18.2 kombu-5.3.1 markdown-3.3.6 mljar-mercury-1.1.6 psutil-5.8.0 pyee-8.2.2 pyppeteer-1.0.2 python-dotenv-0.19.2 shortuuid-1.0.11 sqlalchemy-1.4.27 vine-5.0.0 websockets-10.4 whitenoise-5.3.0 zope.event-4.6 zope.interface-6.0

# %%
mercury add --notebook "https://colab.research.google.com/drive/1W8Lnivlx_cc95NuJeQJX_Ibx-szw394_"
# Out:
#   File "/tmp/ipykernel_10335/2255873372.py", line 1
#     mercury add --notebook "https://colab.research.google.com/drive/1W8Lnivlx_cc95NuJeQJX_Ibx-szw394_"
#             ^
# SyntaxError: invalid syntax

# %%
mercury run
# Out:
#   File "C:\Users\ITTECH~1\AppData\Local\Temp/ipykernel_8952/4065731860.py", line 1
#     mercury run
#             ^
# SyntaxError: invalid syntax
